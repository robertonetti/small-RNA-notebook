# %% [markdown]
# # Upload and unzip data

# %%
using ZipFile
zip_file = "/content/data.zip"
destination_folder = ""
mkpath(destination_folder)
r = ZipFile.Reader(zip_file)
for f in r.files
    if endswith(f.name, "/")
        continue
    end
    output_path = joinpath(destination_folder, f.name)
    mkpath(dirname(output_path))
    open(output_path, "w") do io
        write(io, read(f))
    end
end
close(r)
println("Decompressione completata in: ", destination_folder)
# Out:
# Decompressione completata in:

# %% [markdown]
# # Checking the Installation
# The `versioninfo()` function should print your Julia version and some other info about the system:

# %%
versioninfo()
# Out:
# Julia Version 1.11.5
# Commit 760b2e5b739 (2025-04-14 06:53 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 2 × AMD EPYC 7B12
#   WORD_SIZE: 64
#   LLVM: libLLVM-16.0.6 (ORCJIT, znver2)
# Threads: 2 default, 0 interactive, 1 GC (on 2 virtual cores)
# Environment:
#   LD_LIBRARY_PATH = /usr/local/nvidia/lib:/usr/local/nvidia/lib64
#   JULIA_NUM_THREADS = auto

# %% [markdown]
# # Add Packages

# %%
using Pkg; Pkg.add(url="https://github.com/FrancescoCalvanese/FCSeqTools.jl");
using FCSeqTools, StatsBase, Statistics, LinearAlgebra, PyCall, PyPlot;
include("utils.jl");
using .utils;
# Out:
#     Updating git-repo `https://github.com/FrancescoCalvanese/FCSeqTools.jl`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %% [markdown]
# ---
# # **Section 1:**  Training an eaDCA Model on RNA Structures
#
# ## We will begin by training an eaDCA model on a specific RNA family, which is known to fold into a **internal loop** structure. After conducting some analysis on the internal loop structure, we will proceed to another structure called the **hairpin**.
#
#
# ![structures.svg](data:image/svg+xml;base64,...)
#
# ## Some useful functions:
#
# ``` julia
# data = read_fasta(file_path::String)
# """
# Parameters:
# file_path: The path to the FASTA file (use " ").
#
# Returns:
# data: A matrix containing the sequences represented as Potts spins.
# """
# ```
#
# ```julia
# results = eaDCA(q::Int, lambda::Float, nchains::Int, data::Matrix{Int}, output_file::String)
# """
# Train Potts model with edge activation algorithm.
#
# Parameters:
# q           : The number of nucleotides (use 4).
# lambda      : The regularization parameter (use 0.1).
# nchains     : The number of sequences used by the algorithm to train the model (use 7,000).
# data        : The matrix containing the training data.
# output_file : The name of the output file where results will be saved. (example: eaDCA_output.txt)
#
# Returns:
# score           : A vector depicting the scores acquired throughout the training phases.
# likelihood_gain : A vector showcasing the likelihood gains acquired during the training phases.
# sequences       : The artificial sequences generated by the model.
# J               : A matrix representing the coupling within the model.
# h               : A vector containing the local fields learned by the model.
# contact_list    : The contact list derived from the learned graph.
# site_degree     : The site degree derived from the learned graph.
# edge_list       : The edge list derived from the learned graph.
# """
# ```
# you can access the **generated sequences**, **J** and **h** as:
# ```julia
# sequences = results[3]
# J = results[4]
# h = results[5]
# ```
#
# ---
# ## **Task 1:** Train the eaDCA model on the Internal Loop RNA family.
#
# The file "/content/data/train_sequences_1.fasta" contains natural sequences for the Internal Loop RNA. Use the ```read_fasta()``` function to load the data and ```eaDCA()``` to train a model. Extract the **generated sequences**, the coupling matrix **J**, and the local fields **h**.

# %%
# set some parameters
q = 4 # number of nucleotides
L = 30 # length of the sequences
lambda = 0.1 # regularization
nchains = 7000 # number of sequences for training
output_file_intloop = "output_intloop.txt" ;

# %%
data_intloop = read_fasta("/content/data/train_sequences_1.fasta")
results_intloop = eaDCA(q, lambda, nchains, data_intloop, output_file_intloop);
# Out:
# Fully connected model has 435 edges and a score around ~ 0.95
#
# L = 30               Profile Model :    Score = 0.012    <E> = 39.4    log(Z) = 0.0   S = 39.4   e_t  = 2.11
#
# [13  18]  iter: 1   edges: 1   complex: 0.23%
# [5  26]  iter: 2   edges: 2   complex: 0.46%
# [2  29]  iter: 3   edges: 3   complex: 0.69%
# [4  27]  iter: 4   edges: 4   complex: 0.92%
# [12  19]  iter: 5   edges: 5   complex: 1.15%
# [11  20]  iter: 6   edges: 6   complex: 1.38%
# [3  28]  iter: 7   edges: 7   complex: 1.61%
# [10  21]  iter: 8   edges: 8   complex: 1.84%
# [6  25]  iter: 9   edges: 9   complex: 2.07%
# [9  22]  iter: 10   edges: 10   complex: 2.3%
# [1  30]  iter: 11   edges: 11   complex: 2.53%
# [8  23]  iter: 12   edges: 12   complex: 2.76%
# [7  16]  iter: 13   edges: 13   complex: 2.99%
# [13  23]  iter: 14   edges: 14   complex: 3.22%
# [10  20]  iter: 15   edges: 15   complex: 3.45%   Score = 0.823    <E> = 32.04    log(Z) = 0.25   S = 32.29   e_t  = 5.51
# [12  22]  iter: 16   edges: 16   complex: 3.68%
# [6  21]  iter: 17   edges: 17   complex: 3.91%
# [11  17]  iter: 18   edges: 18   complex: 4.14%
# [1  29]  iter: 19   edges: 19   complex: 4.37%
# [3  5]  iter: 20   edges: 20   complex: 4.6%
# [12  19]  iter: 21   edges: 20   complex: 4.6%
# [4  27]  iter: 22   edges: 20   complex: 4.6%
# [6  24]  iter: 23   edges: 21   complex: 4.83%
# [1  11]  iter: 24   edges: 22   complex: 5.06%
# [10  21]  iter: 25   edges: 22   complex: 5.06%
# [5  11]  iter: 26   edges: 23   complex: 5.29%
# [3  28]  iter: 27   edges: 23   complex: 5.29%
# [8  22]  iter: 28   edges: 24   complex: 5.52%
# [2  29]  iter: 29   edges: 24   complex: 5.52%
# [18  26]  iter: 30   edges: 25   complex: 5.75%   Score = 0.843    <E> = 31.01    log(Z) = 0.49   S = 31.5   e_t  = 7.97
# [21  28]  iter: 31   edges: 26   complex: 5.98%
# [17  26]  iter: 32   edges: 27   complex: 6.21%
# [8  21]  iter: 33   edges: 28   complex: 6.44%
# [11  19]  iter: 34   edges: 29   complex: 6.67%
# [4  15]  iter: 35   edges: 30   complex: 6.9%
# [14  19]  iter: 36   edges: 31   complex: 7.13%
# [11  20]  iter: 37   edges: 31   complex: 7.13%
# [2  27]  iter: 38   edges: 32   complex: 7.36%
# [13  18]  iter: 39   edges: 32   complex: 7.36%
# [2  20]  iter: 40   edges: 33   complex: 7.59%
# [15  19]  iter: 41   edges: 34   complex: 7.82%
# [13  28]  iter: 42   edges: 35   complex: 8.05%
# [2  17]  iter: 43   edges: 36   complex: 8.28%
# [2  22]  iter: 44   edges: 37   complex: 8.51%
# [23  29]  iter: 45   edges: 38   complex: 8.74%   Score = 0.864    <E> = 30.38    log(Z) = 0.64   S = 31.02   e_t  = 10.57
# [9  27]  iter: 46   edges: 39   complex: 8.97%
# [19  28]  iter: 47   edges: 40   complex: 9.2%
# [6  19]  iter: 48   edges: 41   complex: 9.43%
# [5  26]  iter: 49   edges: 41   complex: 9.43%
# [22  28]  iter: 50   edges: 42   complex: 9.66%
# [14  17]  iter: 51   edges: 43   complex: 9.89%
# [14  15]  iter: 52   edges: 44   complex: 10.11%
# [6  20]  iter: 53   edges: 45   complex: 10.34%
# [14  24]  iter: 54   edges: 46   complex: 10.57%
# [13  30]  iter: 55   edges: 47   complex: 10.8%
# [23  28]  iter: 56   edges: 48   complex: 11.03%
# [14  29]  iter: 57   edges: 49   complex: 11.26%
# [12  30]  iter: 58   edges: 50   complex: 11.49%
# [25  26]  iter: 59   edges: 51   complex: 11.72%
# [17  28]  iter: 60   edges: 52   complex: 11.95%   Score = 0.881    <E> = 29.93    log(Z) = 0.77   S = 30.7   e_t  = 13.83
# [25  29]  iter: 61   edges: 53   complex: 12.18%
# [25  27]  iter: 62   edges: 54   complex: 12.41%
# [13  15]  iter: 63   edges: 55   complex: 12.64%
# [10  18]  iter: 64   edges: 56   complex: 12.87%
# [1  4]  iter: 65   edges: 57   complex: 13.1%
# [8  11]  iter: 66   edges: 58   complex: 13.33%
# [13  19]  iter: 67   edges: 59   complex: 13.56%
# [2  19]  iter: 68   edges: 60   complex: 13.79%
# [1  8]  iter: 69   edges: 61   complex: 14.02%
# [18  29]  iter: 70   edges: 62   complex: 14.25%
# [13  20]  iter: 71   edges: 63   complex: 14.48%
# [15  17]  iter: 72   edges: 64   complex: 14.71%
# [19  24]  iter: 73   edges: 65   complex: 14.94%
# [5  22]  iter: 74   edges: 66   complex: 15.17%
# [12  25]  iter: 75   edges: 67   complex: 15.4%   Score = 0.898    <E> = 29.66    log(Z) = 0.84   S = 30.49   e_t  = 16.85
# [18  22]  iter: 76   edges: 68   complex: 15.63%
# [17  22]  iter: 77   edges: 69   complex: 15.86%
# [24  30]  iter: 78   edges: 70   complex: 16.09%
# [12  29]  iter: 79   edges: 71   complex: 16.32%
# [21  23]  iter: 80   edges: 72   complex: 16.55%
# [3  6]  iter: 81   edges: 73   complex: 16.78%
# [9  29]  iter: 82   edges: 74   complex: 17.01%
# [15  22]  iter: 83   edges: 75   complex: 17.24%
# [1  25]  iter: 84   edges: 76   complex: 17.47%
# [14  18]  iter: 85   edges: 77   complex: 17.7%
# [23  26]  iter: 86   edges: 78   complex: 17.93%
# [22  24]  iter: 87   edges: 79   complex: 18.16%
# [1  24]  iter: 88   edges: 80   complex: 18.39%
# [6  18]  iter: 89   edges: 81   complex: 18.62%
# [17  18]  iter: 90   edges: 82   complex: 18.85%   Score = 0.907    <E> = 29.4    log(Z) = 0.93   S = 30.33   e_t  = 20.09
# [3  15]  iter: 91   edges: 83   complex: 19.08%
# [15  29]  iter: 92   edges: 84   complex: 19.31%
# [8  9]  iter: 93   edges: 85   complex: 19.54%
# [8  24]  iter: 94   edges: 86   complex: 19.77%
# [5  27]  iter: 95   edges: 87   complex: 20.0%
# [12  21]  iter: 96   edges: 88   complex: 20.23%
# [26  30]  iter: 97   edges: 89   complex: 20.46%
# [4  13]  iter: 98   edges: 90   complex: 20.69%
# [9  13]  iter: 99   edges: 91   complex: 20.92%
# [5  14]  iter: 100   edges: 92   complex: 21.15%
# [14  20]  iter: 101   edges: 93   complex: 21.38%
# [6  8]  iter: 102   edges: 94   complex: 21.61%
# [20  30]  iter: 103   edges: 95   complex: 21.84%
# [12  20]  iter: 104   edges: 96   complex: 22.07%
# [1  18]  iter: 105   edges: 97   complex: 22.3%   Score = 0.918    <E> = 29.11    log(Z) = 1.03   S = 30.14   e_t  = 23.97
# [17  19]  iter: 106   edges: 98   complex: 22.53%
# [5  21]  iter: 107   edges: 99   complex: 22.76%
# [10  24]  iter: 108   edges: 100   complex: 22.99%
# [20  22]  iter: 109   edges: 101   complex: 23.22%
# [6  30]  iter: 110   edges: 102   complex: 23.45%
# [6  15]  iter: 111   edges: 103   complex: 23.68%
# [11  23]  iter: 112   edges: 104   complex: 23.91%
# [3  24]  iter: 113   edges: 105   complex: 24.14%
# [23  24]  iter: 114   edges: 106   complex: 24.37%
# [2  3]  iter: 115   edges: 107   complex: 24.6%
# [4  21]  iter: 116   edges: 108   complex: 24.83%
# [6  10]  iter: 117   edges: 109   complex: 25.06%
# [14  25]  iter: 118   edges: 110   complex: 25.29%
# [3  4]  iter: 119   edges: 111   complex: 25.52%
# [1  23]  iter: 120   edges: 112   complex: 25.75%   Score = 0.925    <E> = 28.87    log(Z) = 1.13   S = 29.99   e_t  = 27.61
# [8  28]  iter: 121   edges: 113   complex: 25.98%
# [15  21]  iter: 122   edges: 114   complex: 26.21%
# [14  21]  iter: 123   edges: 115   complex: 26.44%
# [3  12]  iter: 124   edges: 116   complex: 26.67%
# [2  8]  iter: 125   edges: 117   complex: 26.9%
# [4  14]  iter: 126   edges: 118   complex: 27.13%
# [9  22]  iter: 127   edges: 118   complex: 27.13%
# [11  25]  iter: 128   edges: 119   complex: 27.36%
# [27  30]  iter: 129   edges: 120   complex: 27.59%
# [6  23]  iter: 130   edges: 121   complex: 27.82%
# [20  27]  iter: 131   edges: 122   complex: 28.05%
# [1  14]  iter: 132   edges: 123   complex: 28.28%
# [3  22]  iter: 133   edges: 124   complex: 28.51%
# [19  26]  iter: 134   edges: 125   complex: 28.74%
# [12  23]  iter: 135   edges: 126   complex: 28.97%   Score = 0.931    <E> = 28.53    log(Z) = 1.23   S = 29.76   e_t  = 31.44
# [1  5]  iter: 136   edges: 127   complex: 29.2%
# [9  21]  iter: 137   edges: 128   complex: 29.43%
# [10  17]  iter: 138   edges: 129   complex: 29.66%
# [14  22]  iter: 139   edges: 130   complex: 29.89%
# [9  23]  iter: 140   edges: 131   complex: 30.11%
# [5  9]  iter: 141   edges: 132   complex: 30.34%
# [4  6]  iter: 142   edges: 133   complex: 30.57%
# [6  25]  iter: 143   edges: 133   complex: 30.57%
# [18  24]  iter: 144   edges: 134   complex: 30.8%
# [8  30]  iter: 145   edges: 135   complex: 31.03%
# [2  13]  iter: 146   edges: 136   complex: 31.26%
# [15  24]  iter: 147   edges: 137   complex: 31.49%
# [4  17]  iter: 148   edges: 138   complex: 31.72%
# [3  30]  iter: 149   edges: 139   complex: 31.95%
# [8  18]  iter: 150   edges: 140   complex: 32.18%   Score = 0.938    <E> = 28.26    log(Z) = 1.33   S = 29.59   e_t  = 35.94
# [18  20]  iter: 151   edges: 141   complex: 32.41%
# [11  24]  iter: 152   edges: 142   complex: 32.64%
# [4  8]  iter: 153   edges: 143   complex: 32.87%
# [24  27]  iter: 154   edges: 144   complex: 33.1%
# [23  30]  iter: 155   edges: 145   complex: 33.33%
# [1  22]  iter: 156   edges: 146   complex: 33.56%
# [17  30]  iter: 157   edges: 147   complex: 33.79%
# [17  20]  iter: 158   edges: 148   complex: 34.02%
# [5  6]  iter: 159   edges: 149   complex: 34.25%
# [17  24]  iter: 160   edges: 150   complex: 34.48%
# [1  21]  iter: 161   edges: 151   complex: 34.71%
# [4  11]  iter: 162   edges: 152   complex: 34.94%
# [21  30]  iter: 163   edges: 153   complex: 35.17%
# [3  21]  iter: 164   edges: 154   complex: 35.4%
# [3  25]  iter: 165   edges: 155   complex: 35.63%   Score = 0.943    <E> = 28.05    log(Z) = 1.41   S = 29.46   e_t  = 40.22
# [1  6]  iter: 166   edges: 156   complex: 35.86%
# [12  13]  iter: 167   edges: 157   complex: 36.09%
# [13  21]  iter: 168   edges: 158   complex: 36.32%
# [1  26]  iter: 169   edges: 159   complex: 36.55%
# [7  27]  iter: 170   edges: 160   complex: 36.78%
# [11  15]  iter: 171   edges: 161   complex: 37.01%
# [19  27]  iter: 172   edges: 162   complex: 37.24%
# [9  24]  iter: 173   edges: 163   complex: 37.47%
# [9  30]  iter: 174   edges: 164   complex: 37.7%
# [1  20]  iter: 175   edges: 165   complex: 37.93%
# [3  10]  iter: 176   edges: 166   complex: 38.16%
# [28  29]  iter: 177   edges: 167   complex: 38.39%
# [3  18]  iter: 178   edges: 168   complex: 38.62%
# [2  9]  iter: 179   edges: 169   complex: 38.85%
# [10  22]  iter: 180   edges: 170   complex: 39.08%   Score = 0.946    <E> = 27.86    log(Z) = 1.51   S = 29.37   e_t  = 44.67
# [2  21]  iter: 181   edges: 171   complex: 39.31%
# [13  25]  iter: 182   edges: 172   complex: 39.54%
# [5  24]  iter: 183   edges: 173   complex: 39.77%
# [22  25]  iter: 184   edges: 174   complex: 40.0%
# [9  14]  iter: 185   edges: 175   complex: 40.23%
# [8  15]  iter: 186   edges: 176   complex: 40.46%
# [5  10]  iter: 187   edges: 177   complex: 40.69%
# [3  11]  iter: 188   edges: 178   complex: 40.92%
# [9  18]  iter: 189   edges: 179   complex: 41.15%
# [2  28]  iter: 190   edges: 180   complex: 41.38%
# [8  25]  iter: 191   edges: 181   complex: 41.61%
# [8  26]  iter: 192   edges: 182   complex: 41.84%
# [21  26]  iter: 193   edges: 183   complex: 42.07%
# [11  26]  iter: 194   edges: 184   complex: 42.3%
# [2  15]  iter: 195   edges: 185   complex: 42.53%   Score = 0.947    <E> = 27.79    log(Z) = 1.6   S = 29.39   e_t  = 49.83
# [4  29]  iter: 196   edges: 186   complex: 42.76%
# [9  17]  iter: 197   edges: 187   complex: 42.99%
# [4  23]  iter: 198   edges: 188   complex: 43.22%
# [6  13]  iter: 199   edges: 189   complex: 43.45%
# [9  12]  iter: 200   edges: 190   complex: 43.68%
# [13  14]  iter: 201   edges: 191   complex: 43.91%
# [2  29]  iter: 202   edges: 191   complex: 43.91%
# [12  24]  iter: 203   edges: 192   complex: 44.14%
# [6  9]  iter: 204   edges: 193   complex: 44.37%
# [9  25]  iter: 205   edges: 194   complex: 44.6%
# [6  17]  iter: 206   edges: 195   complex: 44.83%
# [14  28]  iter: 207   edges: 196   complex: 45.06%
# [19  22]  iter: 208   edges: 197   complex: 45.29%
# [20  29]  iter: 209   edges: 198   complex: 45.52%
# [14  23]  iter: 210   edges: 199   complex: 45.75%   Score = 0.949    <E> = 27.59    log(Z) = 1.73   S = 29.31   e_t  = 54.68
# [10  14]  iter: 211   edges: 200   complex: 45.98%
# [8  10]  iter: 212   edges: 201   complex: 46.21%
# [8  23]  iter: 213   edges: 201   complex: 46.21%
# [10  21]  iter: 214   edges: 201   complex: 46.21%
# [11  28]  iter: 215   edges: 202   complex: 46.44%
# [2  25]  iter: 216   edges: 203   complex: 46.67%
# [1  19]  iter: 217   edges: 204   complex: 46.9%
# [9  11]  iter: 218   edges: 205   complex: 47.13%
# [5  20]  iter: 219   edges: 206   complex: 47.36%
# [5  15]  iter: 220   edges: 207   complex: 47.59%
# [1  28]  iter: 221   edges: 208   complex: 47.82%
# [6  14]  iter: 222   edges: 209   complex: 48.05%
# [12  14]  iter: 223   edges: 210   complex: 48.28%
# [7  16]  iter: 224   edges: 210   complex: 48.28%
# [18  19]  iter: 225   edges: 211   complex: 48.51%   Score = 0.953    <E> = 27.16    log(Z) = 1.85   S = 29.0   e_t  = 60.18
#
# The selceted model has 211 edges and a score = 0.95

# %%
gen_sequences_intloop = results_intloop[3]
J_intloop = results_intloop[4]
h_intloop = results_intloop[5];

# %% [markdown]
# ---
# ## **Task 2**: Demonstrate that the model's energy landscape accurately represents the natural sequences.
#
# Use the ```sequences_energy()``` function to calculate the energies of both the natural and generated sequences. Compare their energy distributions using the histogram below. Do they match?
#
# ```julia
# energies = sequences_energy(data::Matrix{Int}, q::Int, h::Vector{Float}, J::Matrix{Float})
# """
# Parameters:
# - data: A matrix of training data, where each row represents a sequence.
# - q: An integer representing the number of nucleotides.
# - h: A vector of floats representing the local fields learned by the model.
# - J: A matrix of floats representing the coupling between elements in the model.
#
# Output:
# - energies: A vector of floats containing the energy values for each sequence in the dataset.
# """
# ```

# %%
energy_nat_intloop = sequences_energy(data_intloop, q, h_intloop, J_intloop)
energy_gen_intloop = sequences_energy(gen_sequences_intloop, q, h_intloop, J_intloop);

# %%
# histogram
num_bins = 40
plt.figure(figsize=(10, 5))
plt.hist(energy_nat_intloop, label="natural sequences", bins=num_bins, alpha=0.5, color="blue", edgecolor="black", density=true)
plt.hist(energy_gen_intloop, label="generated sequences", bins=num_bins, alpha=0.5, color="green", edgecolor="black", density=true)
plt.title("Compare Energy")
plt.xlabel("energy")
plt.ylabel("counts")
plt.legend()
plt.show()
# Out:
# Figure(PyObject <Figure size 1000x500 with 1 Axes>)

# %% [markdown]
# # **Section 2:** Secondary Structure Prediction
# ---
# ## **Task 1:** Visualize the secondary structure of the Internal Loop RNA family
#
# The file "/content/data/structures_1.txt" contains the **TRUE secondary structure** of the Internal Loop RNA. Use the ```read_secondary_structure()``` function to load the file, then plot it using the code provided below.
#
#
# ```julia
# contact_matrix = read_secondary_structure(file_path::String)
# """
# Read the secondary structure information from a file.
#
# Parameters:
# - file_path: Path to the file containing the secondary structure information (use " ").
#
# Output:
# - contact_matrix: Matrix where each element (i, j) contains either 1 or 0, indicating whether residues i and j form a contact or not.
# """
#
# ```

# %%
# read contact map from file
contact_matrix_intloop = read_secondary_strucuture("/content/data/structures_1.txt")

# plot contacts
contacts = findall(x -> x .> 0, contact_matrix_intloop)
x = getindex.(contacts, 1)
y = getindex.(contacts, 2)
plt.figure(figsize=(7, 7))
plt.scatter(y, x, label="contacts", color="blue")
plt.xlim(0, 31)
plt.ylim(0, 31)
plt.title("Internal Loop Secondary Structure")
plt.xlabel("Nucleotide Positions")
plt.ylabel("Nucleotide Positions")
plt.grid()
plt.legend()
plt.show()
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)

# %% [markdown]
# ---
# ## **Task 2:** Predict the contacts of the Internal Loop RNA using the DCA model and compare them to the true contacts.
#
# Use the ```frobenius_norm()``` function to calculate the norm of the coupling matrix **J**. Then, use the ```plot_contact_map()``` function to visualize the predicted contact map and compare it to the true contact map.
#
#
# ```julia
# J_normalized = frobenius_norm(J::Matrix{Float}, q::Int, L::Int)
# """
# Calculate the Frobenius norm of the coupling matrix.
#
# Parameters:
# - J: Coupling matrix representing pairwise interactions.
# - q: Number of nucleotides.
# - L: Length of the sequence.
#
# Output:
# - J_normalized: LxL matrix containing the Frobenius norm of the coupling matrix.
# """
# ```
#
# ```julia
# plot_contact_map(predicted_contact_matrix::Matrix{Float}, true_contact_matrix::Matrix{Int}, threshold::Float)
# """
# Plot the contact map based on predicted and true contact matrices.
#
# Parameters:
# - predicted_contact_matrix: LxL matrix containing predicted contact values.
# - true_contact_matrix: True contact matrix.
# - threshold: Threshold value for cutting off the predicted contact matrix (try with 1).
# """
# ```

# %%
threshold = 8
J_intloop_normalized = frobenius_norm(J_intloop, q, L)
plot_contact_map(J_intloop_normalized, contact_matrix_intloop, threshold)
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)

# %% [markdown]
# ## - A link $(i, j)$ is considered a predicted contact only if $J_{ij}^{norm} \geq \text{threshold}$. Adjust the **threshold** to improve the clarity of the secondary structure signal.
# ## - Why do you think the pairings **(6,25)** and **(9,22)** are so challenging to distinguish from the true contacts?

# %% [markdown]
# # **Section 3:** Predicting Fitness in a *Deep Mutational Scan* (DMS)
#
# ## Exploring another RNA family: the **hairpin**
#
# > In the *data* folder, you’ll find several files:
# > - Training sequences: "/content/data/train_sequences_2.fasta" (natural hairpin sequences).
# > - DMS sequences: "/content/data/DMS_2.fasta" (mutated sequences for prediction).
# > - Experimental fitness: "/content/data/fitness_DMS_2.txt" (measured fitness values for the DMS sequences).
#
# ---
# ## **Task 1:** How can we predict fitness outcomes accurately in a DMS experiment?
#
# Use the ```read_fitness()``` function to load the fitness file and ```read_fasta()``` to load the DMS sequences. Train a model on the new hairpin dataset, then use **J** and **h** from the model to predict the fitness of the DMS sequences. (Hint: you can do this easily with one of the previously used functions!). Finally, plot the true fitness against your predictions using ```plot_DMS_prediction()```. Discuss the results.
# ```julia
# fitness = read_fitness(file_path::String)
# """
# Read fitness values from a .txt file.
#
# Parameters:
# - file_path: Path to the .txt file containing the fitness values.
#
# Output:
# - fitness: Vector containing the fitness values.
# """
# ```
#
#
# ```julia
# plot_DMS_prediction(fitness, score_vector)
# """
# Plot experimental fitness against prediction scores for each mutation.
#
# Parameters:
# - fitness: Vector containing the experimental fitness of each mutation.
# - score_vector: Vector containing the prediction score for each mutation.
# """
#
# ```

# %%
data_hirpin = read_fasta("/content/data/train_sequences_2.fasta")
data_DMS = read_fasta("/content/data/DMS_2.fasta")
fitness_DMS = read_fitness( "/content/data/fitness_DMS_2.txt")

output_file_hirpin = "output_hirpin.txt"
results_hirpin = eaDCA(q, lambda, nchains, data_hirpin, output_file_hirpin);
# Out:
# Fully connected model has 435 edges and a score around ~ 0.95
#
# L = 30               Profile Model :    Score = -0.007    <E> = 41.04    log(Z) = 0.0   S = 41.04   e_t  = 0.14
#
# [1  30]  iter: 1   edges: 1   complex: 0.23%
# [10  21]  iter: 2   edges: 2   complex: 0.46%
# [8  23]  iter: 3   edges: 3   complex: 0.69%
# [6  25]  iter: 4   edges: 4   complex: 0.92%
# [5  26]  iter: 5   edges: 5   complex: 1.15%
# [7  24]  iter: 6   edges: 6   complex: 1.38%
# [3  28]  iter: 7   edges: 7   complex: 1.61%
# [9  22]  iter: 8   edges: 8   complex: 1.84%
# [2  29]  iter: 9   edges: 9   complex: 2.07%
# [4  27]  iter: 10   edges: 10   complex: 2.3%
# [11  20]  iter: 11   edges: 11   complex: 2.53%
# [12  19]  iter: 12   edges: 12   complex: 2.76%
# [29  30]  iter: 13   edges: 13   complex: 2.99%
# [11  19]  iter: 14   edges: 14   complex: 3.22%
# [13  18]  iter: 15   edges: 15   complex: 3.45%   Score = 0.829    <E> = 33.23    log(Z) = 0.1   S = 33.33   e_t  = 2.24
# [12  25]  iter: 16   edges: 16   complex: 3.68%
# [12  14]  iter: 17   edges: 17   complex: 3.91%
# [12  17]  iter: 18   edges: 18   complex: 4.14%
# [10  21]  iter: 19   edges: 18   complex: 4.14%
# [3  11]  iter: 20   edges: 19   complex: 4.37%
# [1  30]  iter: 21   edges: 19   complex: 4.37%
# [9  22]  iter: 22   edges: 19   complex: 4.37%
# [4  12]  iter: 23   edges: 20   complex: 4.6%
# [20  22]  iter: 24   edges: 21   complex: 4.83%
# [6  25]  iter: 25   edges: 21   complex: 4.83%
# [22  30]  iter: 26   edges: 22   complex: 5.06%
# [7  24]  iter: 27   edges: 22   complex: 5.06%
# [3  28]  iter: 28   edges: 22   complex: 5.06%
# [13  29]  iter: 29   edges: 23   complex: 5.29%
# [9  13]  iter: 30   edges: 24   complex: 5.52%   Score = 0.843    <E> = 32.11    log(Z) = 0.36   S = 32.47   e_t  = 4.66
# [2  29]  iter: 31   edges: 24   complex: 5.52%
# [18  27]  iter: 32   edges: 25   complex: 5.75%
# [2  14]  iter: 33   edges: 26   complex: 5.98%
# [13  19]  iter: 34   edges: 27   complex: 6.21%
# [7  13]  iter: 35   edges: 28   complex: 6.44%
# [5  26]  iter: 36   edges: 28   complex: 6.44%
# [13  15]  iter: 37   edges: 29   complex: 6.67%
# [8  12]  iter: 38   edges: 30   complex: 6.9%
# [4  27]  iter: 39   edges: 30   complex: 6.9%
# [8  23]  iter: 40   edges: 30   complex: 6.9%
# [1  29]  iter: 41   edges: 31   complex: 7.13%
# [2  30]  iter: 42   edges: 32   complex: 7.36%
# [8  11]  iter: 43   edges: 33   complex: 7.59%
# [21  26]  iter: 44   edges: 34   complex: 7.82%
# [6  30]  iter: 45   edges: 35   complex: 8.05%   Score = 0.854    <E> = 31.23    log(Z) = 0.6   S = 31.83   e_t  = 7.24
# [2  19]  iter: 46   edges: 36   complex: 8.28%
# [10  23]  iter: 47   edges: 37   complex: 8.51%
# [20  30]  iter: 48   edges: 38   complex: 8.74%
# [23  24]  iter: 49   edges: 39   complex: 8.97%
# [11  25]  iter: 50   edges: 40   complex: 9.2%
# [5  22]  iter: 51   edges: 41   complex: 9.43%
# [6  10]  iter: 52   edges: 42   complex: 9.66%
# [19  23]  iter: 53   edges: 43   complex: 9.89%
# [13  14]  iter: 54   edges: 44   complex: 10.11%
# [10  17]  iter: 55   edges: 45   complex: 10.34%
# [12  30]  iter: 56   edges: 46   complex: 10.57%
# [15  29]  iter: 57   edges: 47   complex: 10.8%
# [23  30]  iter: 58   edges: 48   complex: 11.03%
# [21  28]  iter: 59   edges: 49   complex: 11.26%
# [5  23]  iter: 60   edges: 50   complex: 11.49%   Score = 0.874    <E> = 30.92    log(Z) = 0.71   S = 31.63   e_t  = 10.16
# [22  28]  iter: 61   edges: 51   complex: 11.72%
# [5  17]  iter: 62   edges: 52   complex: 11.95%
# [22  23]  iter: 63   edges: 53   complex: 12.18%
# [14  23]  iter: 64   edges: 54   complex: 12.41%
# [11  21]  iter: 65   edges: 55   complex: 12.64%
# [11  26]  iter: 66   edges: 56   complex: 12.87%
# [27  30]  iter: 67   edges: 57   complex: 13.1%
# [2  6]  iter: 68   edges: 58   complex: 13.33%
# [18  21]  iter: 69   edges: 59   complex: 13.56%
# [20  24]  iter: 70   edges: 60   complex: 13.79%
# [22  29]  iter: 71   edges: 61   complex: 14.02%
# [14  19]  iter: 72   edges: 62   complex: 14.25%
# [3  14]  iter: 73   edges: 63   complex: 14.48%
# [1  2]  iter: 74   edges: 64   complex: 14.71%
# [19  28]  iter: 75   edges: 65   complex: 14.94%   Score = 0.889    <E> = 30.53    log(Z) = 0.81   S = 31.35   e_t  = 13.43
# [2  27]  iter: 76   edges: 66   complex: 15.17%
# [3  18]  iter: 77   edges: 67   complex: 15.4%
# [10  14]  iter: 78   edges: 68   complex: 15.63%
# [14  24]  iter: 79   edges: 69   complex: 15.86%
# [12  20]  iter: 80   edges: 70   complex: 16.09%
# [13  28]  iter: 81   edges: 71   complex: 16.32%
# [7  26]  iter: 82   edges: 72   complex: 16.55%
# [3  12]  iter: 83   edges: 73   complex: 16.78%
# [3  30]  iter: 84   edges: 74   complex: 17.01%
# [4  14]  iter: 85   edges: 75   complex: 17.24%
# [14  15]  iter: 86   edges: 76   complex: 17.47%
# [16  24]  iter: 87   edges: 77   complex: 17.7%
# [10  12]  iter: 88   edges: 78   complex: 17.93%
# [13  30]  iter: 89   edges: 79   complex: 18.16%
# [11  17]  iter: 90   edges: 80   complex: 18.39%   Score = 0.898    <E> = 30.24    log(Z) = 0.93   S = 31.17   e_t  = 17.11
# [16  27]  iter: 91   edges: 81   complex: 18.62%
# [25  28]  iter: 92   edges: 82   complex: 18.85%
# [16  18]  iter: 93   edges: 83   complex: 19.08%
# [29  30]  iter: 94   edges: 83   complex: 19.08%
# [4  9]  iter: 95   edges: 84   complex: 19.31%
# [5  27]  iter: 96   edges: 85   complex: 19.54%
# [1  24]  iter: 97   edges: 86   complex: 19.77%
# [16  19]  iter: 98   edges: 87   complex: 20.0%
# [5  19]  iter: 99   edges: 88   complex: 20.23%
# [17  18]  iter: 100   edges: 89   complex: 20.46%
# [4  17]  iter: 101   edges: 90   complex: 20.69%
# [5  14]  iter: 102   edges: 91   complex: 20.92%
# [16  28]  iter: 103   edges: 92   complex: 21.15%
# [1  21]  iter: 104   edges: 93   complex: 21.38%
# [5  16]  iter: 105   edges: 94   complex: 21.61%   Score = 0.91    <E> = 29.94    log(Z) = 1.03   S = 30.97   e_t  = 20.52
# [2  11]  iter: 106   edges: 95   complex: 21.84%
# [18  19]  iter: 107   edges: 96   complex: 22.07%
# [24  28]  iter: 108   edges: 97   complex: 22.3%
# [2  16]  iter: 109   edges: 98   complex: 22.53%
# [21  29]  iter: 110   edges: 99   complex: 22.76%
# [4  11]  iter: 111   edges: 100   complex: 22.99%
# [13  20]  iter: 112   edges: 101   complex: 23.22%
# [11  16]  iter: 113   edges: 102   complex: 23.45%
# [3  10]  iter: 114   edges: 103   complex: 23.68%
# [12  15]  iter: 115   edges: 104   complex: 23.91%
# [15  30]  iter: 116   edges: 105   complex: 24.14%
# [5  6]  iter: 117   edges: 106   complex: 24.37%
# [16  17]  iter: 118   edges: 107   complex: 24.6%
# [11  20]  iter: 119   edges: 107   complex: 24.6%
# [15  28]  iter: 120   edges: 108   complex: 24.83%   Score = 0.915    <E> = 29.62    log(Z) = 1.14   S = 30.76   e_t  = 24.55
# [6  8]  iter: 121   edges: 109   complex: 25.06%
# [11  15]  iter: 122   edges: 110   complex: 25.29%
# [5  15]  iter: 123   edges: 111   complex: 25.52%
# [5  13]  iter: 124   edges: 112   complex: 25.75%
# [10  24]  iter: 125   edges: 113   complex: 25.98%
# [7  29]  iter: 126   edges: 114   complex: 26.21%
# [14  25]  iter: 127   edges: 115   complex: 26.44%
# [19  30]  iter: 128   edges: 116   complex: 26.67%
# [15  23]  iter: 129   edges: 117   complex: 26.9%
# [17  19]  iter: 130   edges: 118   complex: 27.13%
# [2  5]  iter: 131   edges: 119   complex: 27.36%
# [15  24]  iter: 132   edges: 120   complex: 27.59%
# [7  12]  iter: 133   edges: 121   complex: 27.82%
# [17  22]  iter: 134   edges: 122   complex: 28.05%
# [19  20]  iter: 135   edges: 123   complex: 28.28%   Score = 0.926    <E> = 29.41    log(Z) = 1.23   S = 30.64   e_t  = 28.36
# [17  20]  iter: 136   edges: 124   complex: 28.51%
# [6  13]  iter: 137   edges: 125   complex: 28.74%
# [7  9]  iter: 138   edges: 126   complex: 28.97%
# [10  20]  iter: 139   edges: 127   complex: 29.2%
# [3  20]  iter: 140   edges: 128   complex: 29.43%
# [16  21]  iter: 141   edges: 129   complex: 29.66%
# [16  29]  iter: 142   edges: 130   complex: 29.89%
# [10  27]  iter: 143   edges: 131   complex: 30.11%
# [17  28]  iter: 144   edges: 132   complex: 30.34%
# [6  17]  iter: 145   edges: 133   complex: 30.57%
# [8  16]  iter: 146   edges: 134   complex: 30.8%
# [9  21]  iter: 147   edges: 135   complex: 31.03%
# [5  8]  iter: 148   edges: 136   complex: 31.26%
# [7  19]  iter: 149   edges: 137   complex: 31.49%
# [7  14]  iter: 150   edges: 138   complex: 31.72%   Score = 0.931    <E> = 29.14    log(Z) = 1.3   S = 30.44   e_t  = 32.6
# [6  18]  iter: 151   edges: 139   complex: 31.95%
# [12  26]  iter: 152   edges: 140   complex: 32.18%
# [6  15]  iter: 153   edges: 141   complex: 32.41%
# [20  27]  iter: 154   edges: 142   complex: 32.64%
# [18  28]  iter: 155   edges: 143   complex: 32.87%
# [10  13]  iter: 156   edges: 144   complex: 33.1%
# [5  20]  iter: 157   edges: 145   complex: 33.33%
# [5  24]  iter: 158   edges: 146   complex: 33.56%
# [4  13]  iter: 159   edges: 147   complex: 33.79%
# [3  17]  iter: 160   edges: 148   complex: 34.02%
# [3  23]  iter: 161   edges: 149   complex: 34.25%
# [2  10]  iter: 162   edges: 150   complex: 34.48%
# [9  16]  iter: 163   edges: 151   complex: 34.71%
# [5  30]  iter: 164   edges: 152   complex: 34.94%
# [9  30]  iter: 165   edges: 153   complex: 35.17%   Score = 0.938    <E> = 29.0    log(Z) = 1.4   S = 30.4   e_t  = 37.04
# [10  19]  iter: 166   edges: 154   complex: 35.4%
# [5  10]  iter: 167   edges: 155   complex: 35.63%
# [15  18]  iter: 168   edges: 156   complex: 35.86%
# [8  22]  iter: 169   edges: 157   complex: 36.09%
# [8  21]  iter: 170   edges: 158   complex: 36.32%
# [17  23]  iter: 171   edges: 159   complex: 36.55%
# [2  28]  iter: 172   edges: 160   complex: 36.78%
# [11  12]  iter: 173   edges: 161   complex: 37.01%
# [2  15]  iter: 174   edges: 162   complex: 37.24%
# [15  22]  iter: 175   edges: 163   complex: 37.47%
# [12  23]  iter: 176   edges: 164   complex: 37.7%
# [15  19]  iter: 177   edges: 165   complex: 37.93%
# [4  25]  iter: 178   edges: 166   complex: 38.16%
# [13  22]  iter: 179   edges: 167   complex: 38.39%
# [14  17]  iter: 180   edges: 168   complex: 38.62%   Score = 0.943    <E> = 28.78    log(Z) = 1.49   S = 30.28   e_t  = 41.37
# [6  22]  iter: 181   edges: 169   complex: 38.85%
# [11  23]  iter: 182   edges: 170   complex: 39.08%
# [6  7]  iter: 183   edges: 171   complex: 39.31%
# [27  28]  iter: 184   edges: 172   complex: 39.54%
# [11  18]  iter: 185   edges: 173   complex: 39.77%
# [18  22]  iter: 186   edges: 174   complex: 40.0%
# [2  12]  iter: 187   edges: 175   complex: 40.23%
# [20  25]  iter: 188   edges: 176   complex: 40.46%
# [8  18]  iter: 189   edges: 177   complex: 40.69%
# [4  24]  iter: 190   edges: 178   complex: 40.92%
# [6  19]  iter: 191   edges: 179   complex: 41.15%
# [15  27]  iter: 192   edges: 180   complex: 41.38%
# [15  16]  iter: 193   edges: 181   complex: 41.61%
# [9  23]  iter: 194   edges: 182   complex: 41.84%
# [12  27]  iter: 195   edges: 183   complex: 42.07%   Score = 0.946    <E> = 28.6    log(Z) = 1.58   S = 30.18   e_t  = 46.37
# [11  14]  iter: 196   edges: 184   complex: 42.3%
# [24  25]  iter: 197   edges: 185   complex: 42.53%
# [2  29]  iter: 198   edges: 185   complex: 42.53%
# [10  11]  iter: 199   edges: 186   complex: 42.76%
# [14  29]  iter: 200   edges: 187   complex: 42.99%
# [12  22]  iter: 201   edges: 188   complex: 43.22%
# [1  18]  iter: 202   edges: 189   complex: 43.45%
# [15  21]  iter: 203   edges: 190   complex: 43.68%
# [8  20]  iter: 204   edges: 191   complex: 43.91%
# [13  27]  iter: 205   edges: 192   complex: 44.14%
# [14  22]  iter: 206   edges: 193   complex: 44.37%
# [14  30]  iter: 207   edges: 194   complex: 44.6%
# [8  23]  iter: 208   edges: 194   complex: 44.6%
# [8  24]  iter: 209   edges: 195   complex: 44.83%
# [13  24]  iter: 210   edges: 196   complex: 45.06%   Score = 0.949    <E> = 28.33    log(Z) = 1.68   S = 30.01   e_t  = 51.14
# [1  22]  iter: 211   edges: 197   complex: 45.29%
# [9  17]  iter: 212   edges: 198   complex: 45.52%
# [7  11]  iter: 213   edges: 199   complex: 45.75%
# [19  22]  iter: 214   edges: 200   complex: 45.98%
# [4  19]  iter: 215   edges: 201   complex: 46.21%
# [7  17]  iter: 216   edges: 202   complex: 46.44%
# [25  30]  iter: 217   edges: 203   complex: 46.67%
# [4  15]  iter: 218   edges: 204   complex: 46.9%
# [20  29]  iter: 219   edges: 205   complex: 47.13%
# [9  28]  iter: 220   edges: 206   complex: 47.36%
# [1  11]  iter: 221   edges: 207   complex: 47.59%
# [15  17]  iter: 222   edges: 208   complex: 47.82%
# [21  25]  iter: 223   edges: 209   complex: 48.05%
# [10  23]  iter: 224   edges: 209   complex: 48.05%
# [2  18]  iter: 225   edges: 210   complex: 48.28%   Score = 0.953    <E> = 28.18    log(Z) = 1.75   S = 29.92   e_t  = 56.52
#
# The selceted model has 210 edges and a score = 0.95

# %%
gen_sequences_hirpin = results_hirpin[3]
J_hirpin = results_hirpin[4]
h_hirpin = results_hirpin[5]
energy_DMS_hirpin = sequences_energy(data_DMS, q, h_hirpin, J_hirpin);

# %%
plot_DMS_prediction(fitness_DMS, energy_DMS_hirpin)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # **(BONUS) Section 4:** Family assignment
#
# ### Considering the two RNA families we've examined (*hairpin* and *interior loop*), we aim to classify a generic sequence into one of these two families. How can we tackle this challenge?
#
# ---
# # **Task 1:** perform a logistic regression and compute the accuracy.
#
#
# > - File with sequences to assign and true label: "/content/data/sequences_to_assign.fasta"
#
#
#
#
# ```julia
# sequences, labels = read_sequences_and_labels(file_path::String)
# """
# Read sequences and their corresponding labels from a file.
#
# Parameters:
# - file_path: Path to the file containing sequences and labels.
#
# Returns:
# - sequences: Vector of sequences read from the file.
# - labels: Vector of labels corresponding to each sequence.
# """
# ```

# %%
# assign the corresponding variable
data_hirpin = data_hirpin
data_intloop = data_intloop
sequences_to_assign, labels = read_sequences_and_labels("/content/data/sequences_to_assign.fasta");

# %%
@pyimport sklearn.linear_model as lm
@pyimport sklearn.metrics as metrics


LR = lm.LogisticRegression()

# create dataset containing sequences of family 1 and 2
data_train = vcat(data_intloop, data_hirpin)
# define the labels
labels_tot = ones(size(data_train, 1))
labels_tot[size(data_hirpin, 1) + 1 : end] .+= 1;

# fit logistic regression
LR.fit(one_hot_encoding(data_train, q), labels_tot)
LR_prediction = LR.predict(one_hot_encoding(sequences_to_assign, q))

# compute the score of the logistic regression
metrics.accuracy_score(LR_prediction, labels)
# Out:
# 0.54

# %% [markdown]
# ---
# ## **Task 2:** Determine a method to assign labels to the sequences utilizing the trained models and compute its accuracy.
# Hint: Plot the histogram of the energies for the sequences to assign, computed with one of the two models. What do you observe? How can you differentiate between hairpin and internal loop RNA?

# %%
energy_seqtossign = sequences_energy(sequences_to_assign, q, h_hirpin, J_hirpin);

# %%
# histogram
num_bins = 40
plt.figure(figsize=(10, 5))
plt.hist(energy_seqtossign, label="sequences to assign", bins=num_bins, alpha=0.5, color="blue", edgecolor="black", density=true)
plt.title("Energy computed with Hirpin model")
plt.xlabel("energy")
plt.ylabel("counts")
plt.legend()
plt.show()
# Out:
# Figure(PyObject <Figure size 1000x500 with 1 Axes>)

# %%
N = size(sequences_to_assign, 1) # number of sequences to assign
DCA_prediction = zeros(N)

for i in 1:N
  if energy_seqtossign[i] <= 45
    DCA_prediction[i] = 2
  else
    DCA_prediction[i] = 1
  end
end

metrics.accuracy_score(DCA_prediction, labels)
# Out:
# 1.0

# %% [markdown]
# ---
# # **Mutable sites:** Mutations tend to be more harmful in areas with exceptionally low mutability. A proxy for the mutability of a sequence is represented by the model entropy.
#
#
# ```julia
# ci_entropy = context_independent_entropy(data, q)
#
# """
# Compute context-independent entropy for given dataset.
#
# Parameters:
# - data: Input data for entropy calculation.
# - q: Number of nucleotides.
#
# Returns:
# - ci_entropy: Context-independent entropy.
# """
#
# ```
#
# ```julia
# cd_entropy = context_dependent_entropy(sequence::Vector, L::Int, q::Int, J::Matrix{Float}, h::Vector{Float})
# """
# Compute context-dependent entropy for a given sequence.
#
# Parameters:
# - sequence: Vector representing the sequence.
# - L: Length of the sequence.
# - q: Number of nucleotides.
# - J: Coupling matrix representing pairwise interactions.
# - h: Vector of local fields.
#
# Returns:
# - cd_entropy: Vector containing context-dependent entropy for each position in the sequence.
# """
# ```

# %%
# set J_2 and h_2 as the parameters of the Internal Loop RNA model
J_hirpin = J_hirpin
h_hirpin = h_hirpin;

# %%
# compute context INDEPENDENT entropy from the data
CIE = context_independent_entropy(data_hirpin, q)

plt.bar(1:L, CIE)
plt.title("Contex Independent Entropy")
plt.xlabel("Nucleotide Position")
plt.ylabel("Entropy");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
# compute context DEPENDENT entropy from the model
average_CDE = zeros(Float64, L)
for i in 1:size(data_intloop, 1)
  average_CDE  .+= context_dependent_entropy(data_hirpin[i, :], L, q, J_hirpin, h_hirpin)
end

average_CDE = average_CDE ./ size(data_intloop, 1)
plt.bar(1:L, average_CDE)
plt.title("Contex Dependent Entropy")
plt.xlabel("Nucleotide Position")
plt.ylabel("Entropy");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.scatter(CIE, average_CDE);
plt.title("Context Dependent/Independent Entropy")
plt.xlabel("CIE");
plt.ylabel("CDE");
plt.grid();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # Need Help?
#
# * Learning: https://julialang.org/learning/
# * Documentation: https://docs.julialang.org/
# * Questions & Discussions:
#   * https://discourse.julialang.org/
#   * http://julialang.slack.com/
#   * https://stackoverflow.com/questions/tagged/julia
#
# If you ever ask for help or file an issue about Julia, you should generally provide the output of `versioninfo()`.

# %% [markdown]
# Add new code cells by clicking the `+ Code` button (or _Insert_ > _Code cell_).
#
# Have fun!
#
# <img src="https://raw.githubusercontent.com/JuliaLang/julia-logo-graphics/master/images/julia-logo-mask.png" height="100" />
